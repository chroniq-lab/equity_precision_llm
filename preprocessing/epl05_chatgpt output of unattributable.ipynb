# %%
import pandas as pd 
import numpy as np
import sklearn as sklearn
import os as os

import matplotlib.pyplot as plt
import seaborn as sns
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import re as re

if os.getlogin()=="JVARGH7":
    path_equity_precision_llm_folder = "C:/Cloud/OneDrive - Emory University/Papers/Global Equity in Diabetes Precision Medicine LLM"
    path_equity_precision_llm_repo =  'C:/code/external/equity_precision_llm'

elif os.getlogin()=='aamnasoniwala':
    path_equity_precision_llm_folder = "/Users/aamnasoniwala/Library/CloudStorage/OneDrive-Emory/Global Equity in Diabetes Precision Medicine LLM"
    path_equity_precision_llm_repo = '/Users/aamnasoniwala/code/equity_precision_llm'

# path_equity_precision_llm_folder = "/Users/aamnasoniwala/Library/CloudStorage/OneDrive-Emory/Global Equity in Diabetes Precision Medicine LLM"
# path_equity_precision_llm_repo = '/Users/aamnasoniwala/code/equity_precision_llm'

excel_path = path_equity_precision_llm_folder + "/llm training/Unclassified Splits/Unattributable Part "
# path_equity_precision_llm_repo = os.path.abspath("").replace("preprocessing", "")

execfile(path_equity_precision_llm_repo + "/functions/crosstab_summary.py")

# %%
excel_path_unattributable = path_equity_precision_llm_folder + "/llm training/epldat03_Unattributable Data.csv"
# path_equity_precision_llm_repo = os.path.abspath("").replace("preprocessing", "")

execfile(path_equity_precision_llm_repo + "/functions/clean_input.py")
execfile(path_equity_precision_llm_repo + "/functions/crosstab_summary.py")
execfile(path_equity_precision_llm_repo + "/functions/standardize_population.py")
execfile(path_equity_precision_llm_repo + "/functions/adjusted_source_population_match.py")

# %%
input_unattributable = pd.read_csv(excel_path_unattributable)
input_unattributable.head()
# Out:
#        PMID                                               MeSH  \
# 0  18008027  Albuminuria, Angiotensin II Type 1 Receptor Bl...
# 1  18205795  Antigens, Tumor-Associated, Carbohydrate, Bloo...
# 2  18378359  Age Distribution, Age Factors, Aged, 80 and ov...
# 3  18626579  Bioreactors, Biotechnology, Fermentation, Gluc...
# 4  18651247  Bioreactors, Butyric Acid, Cells, Immobilized,...
#
#                                             Abstract  \
# 0  The purpose of the present study was to invest...
# 1  CA 72-4 is one of the blood group carbohydrate...
# 2  The aim of this study was to evaluate the asso...
# 3  The production of propionic acid by Propioniba...
# 4  Butyric acid has many applications in chemical...
#
#                                                Title  year
# 0  Renoprotective effects of telmisartan on renal...  2013
# 1  CA 72-4 levels in patients with type 2 diabete...  2011
# 2  Vascular risk factors and dementia in the gene...  2010
# 3  Kinetic analysis and pH-shift control strategy...  2010
# 4  Production of butyric acid from glucose and xy...  2010

# %%
import pandas as pd
import re

n_json_splits = 11
# Concatenate multiple CSVs
results = None
for scenario in range(1, n_json_splits + 1):
    file_path = f"{path_equity_precision_llm_folder}/llm training/Unclassified Splits/Unattributable Part {scenario}_results.csv"
    temp_df = pd.read_csv(file_path, na_values=['n/a','NaN'], keep_default_na=False)
    temp_df = temp_df[['pmid', 'title', 'gpt_precision_medicine', 'gpt_diabetes', 'gpt_primary_study', 'gpt_source_population']]

    if results is None:
        results = temp_df
    else:
        results = pd.concat([results, temp_df], ignore_index=True)

# Merge datasets
merged_df_unattributable = input_unattributable.merge(results, left_on='PMID', right_on='pmid', how='left')
merged_df_unattributable['gpt_source_population'] = merged_df_unattributable['gpt_source_population'].apply(standardize_population)

merged_df_unattributable = merged_df_unattributable.drop_duplicates(subset='PMID', keep='first').reset_index(drop=True)
merged_df_unattributable = merged_df_unattributable[merged_df_unattributable['Abstract'].notna()].reset_index(drop=True)
merged_df_unattributable = merged_df_unattributable[
    merged_df_unattributable['gpt_precision_medicine'].notna() &
    (merged_df_unattributable['gpt_precision_medicine'] != 'no (insufficient information)')
].reset_index(drop=True)


merged_df_unattributable.to_csv(f"{path_equity_precision_llm_folder}/llm training/epl05_merged unattributable data.csv", index=False)
merged_df_unattributable.shape
# Out:
# (125923, 11)

# %%
rows, columns = merged_df_unattributable.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 125923
# Number of columns: 11

# %%
unique_source_populations = merged_df_unattributable['gpt_source_population'].unique()
print(unique_source_populations)
# Out:
# ['Unknown' 'we' 'ea' 'na' 'mena' 'cee'
#  'ea, ssa, sa, we, na, cee, mena, seap, ca, lac' 'sa' 'ssa' 'na, lac'
#  'lac' 'seap' 'ea, sa' 'ea, we' 'we, ssa' 'sa, ssa, we' 'ssa, we' 'na, we'
#  'lac, ssa' 'sa, we' 'lac, mena, we' 'sa, na' 'ssa, we, ea, lac' 'ea, na'
#  'ea, sa, we' 'mena, sa' 'we, na' 'na, we, seap' 'we, sa'
#  'we, ea, seap, lac' 'ea, seap' 'ssa, na' 'cee, we' 'lac, mena' 'ca'
#  'ca, mena, ea, we' 'na, ea, ssa, lac' 'na, seap, lac, ssa, we'
#  'na, cee, we' 'na, ssa' 'ea, ssa' 'we, ea' 'seap, we' 'we, mena'
#  'we, ssa, lac, mena' 'we, na, lac' 'na, lac, ssa, we' 'mena, we'
#  'we, sa, ssa' 'na, ea, we' 'na, lac, we, ea'
#  'na, ea, sa, ssa, we, lac, cee, seap, ca, mena' 'na, mena, sa'
#  'seap, ea, sa, we' 'na, we, ssa' 'we, sa, mena' 'lac, we'
#  'ea, sa, we, ssa' 'cee, na' 'ea, cee' 'ea, lac' 'ea, cee, we, na'
#  'cee, ea, lac, ssa' 'ea, aa, sa'
#  'ea, ssa, we, na, cee, seap, sa, ca, mena, lac' 'na, ea, we, sa'
#  'we, cee, ea, lac' 'mena, we, sa' 'ca, cee, ea, lac, mena, seap, sa, ssa'
#  'na, ea, ssa, we' 'ea, seap, sa' 'ea, na, we' 'cee, mena' 'we, ssa, na'
#  'ssa, sa, seap, lac, mena, ea' 'na, lac, ea, we' 'na, we, ea'
#  'ea, ssa, we' 'na, seap, mena' 'sa, cee, ea'
#  'ssa, lac, na, seap, cee, mena' 'ea, cee, ssa, na' 'cee, ea'
#  'na, lac, ea, mena' 'we, ea, lac, seap' 'cee, we, ea'
#  'cee, ea, lac, mena, seap, sa, we, na' 'na, ea, lac' 'lac, na'
#  'we, ea, sa, seap' 'na, ea' 'we, ea, sa' 'we, ssa, sa' 'we, sa, lac'
#  'ea, na, ssa, we' 'ea, lac, na' 'ea, sa, na, lac, we, ssa'
#  'ea, ca, cee, lac, mena, seap, sa, ssa, na, we' 'seap, sa' 'cee, ea, we'
#  'we, lac, na' 'seap, na' 'na, ssa, lac, seap, sa' 'ea, sa, ssa, we'
#  'mena, sa, seap' 'mena, ca, ea, seap, sa, ssa, cee, lac' 'na, cee, ea'
#  'ea, seap, ssa' 'we, ea, na' 'lac, sa, ssa'
#  'na, cee, we, ea, sa, seap, lac, mena, ssa' 'ssa, we, ea'
#  'ea, ssa, we, lac' 'na, lac, cee, we, ea, seap' 'we, ea, na, lac'
#  'we, na, cee, ea, lac, mena, seap, sa, ssa' 'sa, ssa'
#  'cee, na, ssa, we, ea, lac, mena, sa' 'ssa, ea, we' 'ea, sa, we, na'
#  'sa, mena' 'na, ssa, lac, ea' 'mena, sa, ssa'
#  'na, ea, ssa, lac, cee, we, sa, seap, mena, ca' 'sa, seap, we, ssa, ea'
#  'na, cee, we, ea, lac' 'na, cee, we, lac' 'na, ea, lac, ssa'
#  'we, ea, ssa' 'na, ea, ssa' 'mena, ea'
#  'ca, cee, ea, lac, mena, seap, sa, ssa, na, we'
#  'we, na, sa, mena, cee, ea, ssa, seap, lac, ca' 'sa, cee' 'mena, na, we'
#  'mena, na' 'ssa, lac, seap' 'sa, ssa, mena, we'
#  'ca, cee, ea, mena, ssa, we' 'mena, ssa' 'we, na, seap, ssa'
#  'ea, we, ssa' 'na, cee, we, ea' 'na, cee, lac, mena, sa, seap, ssa, we'
#  'na, ea, sa, ssa' 'ea, lac, we' 'ea, seap, lac, na' 'ssa, na, we'
#  'na, ea, sa, we' 'na, we, cee, ea, lac, mena, seap, sa, ssa, ca'
#  'sa, we, ea, ssa' 'we, cee, ea, ssa' 'cee, mena, we' 'lac, ssa, na, we'
#  'ea, we, ssa, ca' 'ea, ssa, na, we, sa, seap, lac, mena, ca, cee'
#  'na, cee, ea, we' 'ea, ssa, sa, lac' 'na, we, mena' 'na, we, ssa, lac'
#  'we, sa, ea' 'mena, cee' 'we, mena, ea' 'ea, mena, na, we'
#  'na, we, cee, lac' 'na, seap, ea, lac, ssa' 'we, ssa, ea, sa, na'
#  'ea, cee, mena, we, seap' 'we, na, ea' 'we, sa, ssa, seap' 'ea, mena'
#  'we, ea, mena, sa, seap' 'na, we, cee, ea, sa, seap, ssa, lac, mena, ca'
#  'sa, lac, seap, ssa' 'we, sa, ssa, mena' 'sa, ea' 'ea, sa, seap'
#  'mena, sa, we, ssa, ea, cee' 'cee, ea, ssa, mena, lac, seap'
#  'ssa, ea, sa, lac' 'we, ea, mena, lac, ssa, sa, seap' 'ssa, mena, sa, we'
#  'ca, mena' 'na, ea, sa' 'ea, ca' 'mena, lac' 'mena, ea, ssa, we'
#  'lac, ssa, we' 'na, we, cee, lac, ea, seap, sa, mena, ssa'
#  'cee, ea, lac, mena, sa, seap, ssa' 'na, ssa, ea, lac, we'
#  'sa, lac, seap, ssa, ea' 'ssa, sa' 'na, ea, we, ssa, lac'
#  'ssa, ea, mena, we, lac, sa, seap' 'cee, na, ea' 'ea, we, na'
#  'ea, lac, ssa' 'ea, ssa, lac, sa, we' 'seap, ssa, lac, na, we'
#  'sa, we, lac' 'na, seap, ea, lac, ssa, we' 'we, lac' 'ea, sa, mena, cee'
#  'ssa, lac, sa, seap, mena' 'seap, sa, ea' 'na, we, lac' 'sa, seap, mena'
#  'ssa, ea, we, na' 'na, ea, sa, lac, ssa'
#  'na, sa, ssa, ea, lac, seap, mena, cee, ca, we' 'ssa, sa, we'
#  'na, cee, we, ea, lac, seap, sa, ssa, mena, ca' 'ea, we, lac, seap'
#  'na, ssa, lac' 'cee, na, we, ea, seap' 'cee, ea, lac, mena, seap, we, na'
#  'na, ea, ssa, cee, we' 'na, we, seap, mena' 'ea, cee, we, ssa, seap, lac'
#  'lac, ssa, na' 'sa, we, ssa' 'mena, ssa, seap'
#  'ca, cee, ea, lac, na, sa, ssa, we' 'na, we, ea, lac, seap, ssa'
#  'ea, seap, we' 'we, ea, na, cee, sa, seap' 'na, we, ssa, ea'
#  'ea, na, mena' 'na, we, ea, cee, lac, mena, seap, sa, ssa, ca' 'ssa, lac'
#  'na, we, lac, ssa' 'cee, ea, ssa, we' 'na, ea, lac, we'
#  'ea, na, sa, we, ssa' 'na, ea, ssa, we, lac, cee, sa'
#  'na, we, cee, ea, ssa, sa' 'cee, we, na'
#  'ca, cee, ea, lac, mena, seap, sa, ssa, we, na' 'ea, na, lac, seap, ssa'
#  'ssa, ea, mena, sa, we' 'we, ea, mena, lac' 'ssa, lac, ea, seap, na, we'
#  'lac, ssa, seap, sa' 'ea, mena, we, sa'
#  'ca, cee, lac, mena, seap, sa, ssa'
#  'na, cee, we, lac, ea, mena, ssa, seap, sa' 'seap, ea, sa'
#  'na, we, ea, sa, ssa, lac, seap, cee, mena, ca' 'na, sa' 'ca, ea'
#  'we, mena, ea, cee, seap, sa, lac, ssa, na, ca' 'na, we, cee'
#  'sa, na, ssa, lac' 'na, we, ea, ssa, sa, lac, cee, seap'
#  'we, ea, na, ssa' 'ea, cee, we' 'ssa, seap' 'we, lac, ca'
#  'we, na, ssa, lac' 'na, ea, cee, we' 'na, mena' 'we, seap' 'we, ea, seap'
#  'cee, ea, lac, mena, seap, sa, ssa, we, na' 'lac, sa' 'we, ssa, sa, mena'
#  'seap, ea, na, lac' 'na, we, ea, ssa, lac, sa' 'na, ea, lac, ssa, we'
#  'ea, we, seap' 'cee, na, we' 'na, lac, ssa'
#  'we, cee, ea, lac, mena, seap, ssa, na' 'na, seap' 'na, we, ea, cee, lac'
#  'na, ssa, cee, we' 'ssa, na, lac' 'we, ssa, na, sa, ea, mena'
#  'ssa, seap, cee' 'we, na, ea, lac' 'na, we, ssa, ea, lac, cee, sa, seap'
#  'we, sa, ssa, mena, seap' 'ea, lac, sa, na'
#  'mena, cee, sa, ssa, seap, we' 'na, ea, we, seap' 'cee, we, ca, seap']

# %%
# Check the output below
merged_df_unattributable.head()
# Out:
#        PMID                                               MeSH  \
# 0  18008027  Albuminuria, Angiotensin II Type 1 Receptor Bl...
# 1  18205795  Antigens, Tumor-Associated, Carbohydrate, Bloo...
# 2  18378359  Age Distribution, Age Factors, Aged, 80 and ov...
# 3  18626579  Bioreactors, Biotechnology, Fermentation, Gluc...
# 4  18651247  Bioreactors, Butyric Acid, Cells, Immobilized,...
#
#                                             Abstract  \
# 0  The purpose of the present study was to invest...
# 1  CA 72-4 is one of the blood group carbohydrate...
# 2  The aim of this study was to evaluate the asso...
# 3  The production of propionic acid by Propioniba...
# 4  Butyric acid has many applications in chemical...
#
#                                                Title  year        pmid  \
# 0  Renoprotective effects of telmisartan on renal...  2013  18008027.0
# 1  CA 72-4 levels in patients with type 2 diabete...  2011  18205795.0
# 2  Vascular risk factors and dementia in the gene...  2010  18378359.0
# 3  Kinetic analysis and pH-shift control strategy...  2010  18626579.0
# 4  Production of butyric acid from glucose and xy...  2010  18651247.0
#
#                                                title gpt_precision_medicine  \
# 0   Renoprotective effects of telmisartan on rena...                     no
# 1   CA 72-4 levels in patients with type 2 diabet...                     no
# 2   Vascular risk factors and dementia in the gen...                     no
# 3   Kinetic analysis and pH-shift control strateg...                     no
# 4   Production of butyric acid from glucose and x...                     no
#
#   gpt_diabetes gpt_primary_study gpt_source_population
# 0          yes               yes               Unknown
# 1          yes               yes               Unknown
# 2          yes               yes                    we
# 3           no               yes               Unknown
# 4           no               yes               Unknown

# %%
import pandas as pd

# Define the valid source population categories
VALID_REGIONS = {"ca", "na", "cee", "lac", "sa", "ssa", "we", "seap", "mena", "ea", "Unknown"}
EUROPEAN_REGIONS = {"we", "na"}
NON_EUROPEAN_REGIONS = VALID_REGIONS - EUROPEAN_REGIONS - {"Unknown"}

# Step 1: Identify and count excluded studies due to missing Title or Abstract
def is_missing(value):
    return pd.isna(value) or str(value).strip() == ""

def excluded(row):
    # return is_missing(row['Title']) or is_missing(row['Abstract']) or is_missing(row['MeSH'])
    return is_missing(row['Title']) or is_missing(row['Abstract'])

# Count excluded studies
excluded_studies_df = merged_df_unattributable[merged_df_unattributable.apply(excluded, axis=1)]
excluded_count = len(excluded_studies_df)
print(f"Number of studies excluded due to missing Abstract: {excluded_count}")

# Apply exclusion
merged_df_unattributable_after_exclusion = merged_df_unattributable.drop(excluded_studies_df.index)

# Verify remaining studies
remaining_studies = len(merged_df_unattributable_after_exclusion)
print(f"Remaining studies after exclusion: {remaining_studies}")

merged_df_unattributable_after_exclusion.shape
# Out:
# Number of studies excluded due to missing Abstract: 0
# Remaining studies after exclusion: 125923
# (125923, 11)

# %%
NON_EUROPEAN_REGIONS

# %%
total_classified_and_unclassified = remaining_studies + excluded_count
print("remaining: " + str(remaining_studies) + "; excluded: " + str(excluded_count) + "; total: " + str(total_classified_and_unclassified))
# Out:
# remaining: 125923; excluded: 0; total: 125923

# %% [markdown]
# #### @Aamna: The below should reflect the number of abstracts that have more than 1 region attached to it.

# %%
# Step 2: Normalize source population categories

def normalize_source_population(source_population):
    if pd.isna(source_population):
        return set()
    return VALID_REGIONS.intersection(set(re.sub(r'\s+', '', source_population).split(',')))

merged_df_unattributable_after_exclusion['normalized_regions'] = merged_df_unattributable_after_exclusion['gpt_source_population'].apply(normalize_source_population)

# Count rows where normalized_regions has more than 1 element
multi_region_rows = merged_df_unattributable_after_exclusion[merged_df_unattributable_after_exclusion['normalized_regions'].apply(lambda x: len(x) > 1)]
multi_region_count = len(multi_region_rows)
print(f"Number of rows where normalized_regions has more than 1 element: {multi_region_count}")
# Out:
# Number of rows where normalized_regions has more than 1 element: 929

# %%
# Step 3: Expand data **only** for regional counts
expanded_rows = []
for _, row in merged_df_unattributable_after_exclusion.iterrows():
    for region in row['normalized_regions']:
        new_row = row.copy()
        new_row['gpt_source_population'] = region
        expanded_rows.append(new_row)

# Create expanded DataFrame for regional counts
expanded_df = pd.DataFrame(expanded_rows)
expanded_df.shape
# Out:
# (127576, 12)

# %%
expanded_df.head(n=20)
# Out:
#         PMID                                               MeSH  \
# 0   18008027  Albuminuria, Angiotensin II Type 1 Receptor Bl...
# 1   18205795  Antigens, Tumor-Associated, Carbohydrate, Bloo...
# 2   18378359  Age Distribution, Age Factors, Aged, 80 and ov...
# 3   18626579  Bioreactors, Biotechnology, Fermentation, Gluc...
# 4   18651247  Bioreactors, Butyric Acid, Cells, Immobilized,...
# 5   18800199  5-Aminolevulinate Synthetase, Aminolevulinic A...
# 6   18809217  Adipocytes, Animals, Blood Glucose, Body Weigh...
# 7   18817993  Aged, Biomarkers, Blood Glucose, Coronary Arte...
# 8   18840627  Adult, Child, DNA-Binding Proteins, Endoplasmi...
# 9   18922591  Adiponectin, Biomarkers, Blood Glucose, Corona...
# 10  18927166  Adiponectin, Carbohydrate Metabolism, Exercise...
# 11  18955282                                                NaN
# 12  18955324                                                NaN
# 13  18955365                                                NaN
# 14  18998207  Cardiomyopathies, Glucose, Heart Failure, Huma...
# 15  19001480                                                NaN
# 16  19019358  Adult, Arginine, Biomarkers, Blood Glucose, C-...
# 17  19051287  Adolescent, Adult, Female, Gene Expression Pro...
# 18  19056300  Animals, Body Weight, Cell Adhesion Molecules,...
# 19  19067246  Fermentation, Gene Expression Regulation, Fung...
#
#                                              Abstract  \
# 0   The purpose of the present study was to invest...
# 1   CA 72-4 is one of the blood group carbohydrate...
# 2   The aim of this study was to evaluate the asso...
# 3   The production of propionic acid by Propioniba...
# 4   Butyric acid has many applications in chemical...
# 5   The 5-aminolevulinate (ALA) synthase gene (hem...
# 6   Tumor necrosis factor-alpha (TNF-alpha) is an ...
# 7   A large clinical trial clarified that pioglita...
# 8   Endoplasmic reticulum stress is a central feat...
# 9   Because of the strong association between abdo...
# 10  Leptin and adiponectin represent two newly dis...
# 11  In women facing menopause, end of menstrual ac...
# 12  Satureja khuzestanica is an endemic plant of I...
# 13  Circulating adhesion molecules (CAMs), surface...
# 14  The PPAR gene pathway consists of interrelated...
# 15  This study was designed to determine whether N...
# 16  To assess the interaction between insulin resi...
# 17  Progress in understanding the genetic basis of...
# 18  Diabetic retinopathy resists arrest of its pro...
# 19  Global transcription machinery engineering (gT...
#
#                                                 Title  year        pmid  \
# 0   Renoprotective effects of telmisartan on renal...  2013  18008027.0
# 1   CA 72-4 levels in patients with type 2 diabete...  2011  18205795.0
# 2   Vascular risk factors and dementia in the gene...  2010  18378359.0
# 3   Kinetic analysis and pH-shift control strategy...  2010  18626579.0
# 4   Production of butyric acid from glucose and xy...  2010  18651247.0
# 5   Expression of a hemA gene from Agrobacterium r...  2010  18800199.0
# 6   Pioglitazone reduces tumor necrosis factor-alp...  2010  18809217.0
# 7   Pioglitazone induces regression of coronary at...  2010  18817993.0
# 8   Relationship between functional promoter polym...  2010  18840627.0
# 9   The presence of abdominal obesity is associate...  2010  18922591.0
# 10  Review on leptin and adiponectin responses and...  2011  18927166.0
# 11  A Kampo Medicine, Boi-ogi-to, Inhibits Obesity...  2011  18955282.0
# 12  Effects of Satureja khuzestanica on Serum Gluc...  2011  18955324.0
# 13  A chinese herbal preparation containing radix ...  2012  18955365.0
# 14  PPAR transcriptional activator complex polymor...  2010  18998207.0
# 15  N-acetylcysteine an allium plant compound impr...  2012  19001480.0
# 16  Endothelial function and insulin resistance in...  2010  19019358.0
# 17  Peripheral gene expression profiling of CCK-4-...  2010  19051287.0
# 18  Resistance of retinal inflammatory mediators t...  2010  19056300.0
# 19  gTME for improved xylose fermentation of Sacch...  2010  19067246.0
#
#                                                 title gpt_precision_medicine  \
# 0    Renoprotective effects of telmisartan on rena...                     no
# 1    CA 72-4 levels in patients with type 2 diabet...                     no
# 2    Vascular risk factors and dementia in the gen...                     no
# 3    Kinetic analysis and pH-shift control strateg...                     no
# 4    Production of butyric acid from glucose and x...                     no
# 5    Expression of a hemA gene from Agrobacterium ...                     no
# 6    Pioglitazone reduces tumor necrosis factor-al...                     no
# 7    Pioglitazone induces regression of coronary a...                     no
# 8    Relationship between functional promoter poly...                    yes
# 9    The presence of abdominal obesity is associat...                     no
# 10   Review on leptin and adiponectin responses an...                     no
# 11   A Kampo Medicine, Boi-ogi-to, Inhibits Obesit...                     no
# 12   Effects of Satureja khuzestanica on Serum Glu...                     no
# 13   A chinese herbal preparation containing radix...                     no
# 14   PPAR transcriptional activator complex polymo...                    yes
# 15   N-acetylcysteine an allium plant compound imp...                     no
# 16   Endothelial function and insulin resistance i...                     no
# 17   Peripheral gene expression profiling of CCK-4...                    yes
# 18   Resistance of retinal inflammatory mediators ...                     no
# 19   gTME for improved xylose fermentation of Sacc...                     no
#
#    gpt_diabetes gpt_primary_study gpt_source_population normalized_regions
# 0           yes               yes               Unknown          {Unknown}
# 1           yes               yes               Unknown          {Unknown}
# 2           yes               yes                    we               {we}
# 3            no               yes               Unknown          {Unknown}
# 4            no               yes               Unknown          {Unknown}
# 5            no               yes               Unknown          {Unknown}
# 6            no               yes               Unknown          {Unknown}
# 7           yes               yes                    we               {we}
# 8            no               yes                    ea               {ea}
# 9            no               yes                    na               {na}
# 10           no                no                    na               {na}
# 11           no                no               Unknown          {Unknown}
# 12          yes               yes                  mena             {mena}
# 13           no               yes                    ea               {ea}
# 14           no                no                    na               {na}
# 15           no               yes               Unknown          {Unknown}
# 16           no               yes                    we               {we}
# 17           no               yes                    we               {we}
# 18          yes               yes               Unknown          {Unknown}
# 19           no                no               Unknown          {Unknown}

# %%
# Step 4: Create a crosstab summary function
def crosstab_summary(expanded_df, categories, region_col='gpt_source_population'):
    expanded_df['combined_category'] = expanded_df[categories].astype(str).agg('_'.join, axis=1)
    summary = pd.crosstab(expanded_df['combined_category'], expanded_df[region_col])
    summary.reset_index(inplace=True)
    return summary

# Define categories
categories = ['gpt_precision_medicine', 'gpt_diabetes', 'gpt_primary_study']

# Generate crosstab for regional counts
summary_expanded_df = crosstab_summary(expanded_df, categories, region_col='gpt_source_population')

# Step 5: Compute overall totals without double-counting studies
total_counts = {
    'Total Precision Medicine': merged_df_unattributable_after_exclusion['gpt_precision_medicine'].notna().sum(),
    'Total Diabetes': merged_df_unattributable_after_exclusion['gpt_diabetes'].notna().sum(),
    'Total Primary Study': merged_df_unattributable_after_exclusion['gpt_primary_study'].notna().sum()
}

total_counts
# Out:
# {'Total Precision Medicine': 125923,
#  'Total Diabetes': 125923,
#  'Total Primary Study': 125923}

# %%
# Step 6: Save the expanded output for regions
output_path = path_equity_precision_llm_repo + '/preprocessing/epl05_combined_output_Unattributable.csv'
summary_expanded_df.to_csv(output_path, index=False)

# Display summary
display(summary_expanded_df)
# Out:
# gpt_source_population combined_category  Unknown  ca   cee    ea  lac  mena  \
# 0                              no_no_no     7099   5    75   337   52    58
# 1                             no_no_yes    22122  29  1400  2931  523  1142
# 2                             no_yes_no     2763   6   106   460   34    91
# 3                            no_yes_yes    12919  18  1523  3778  571  1382
# 4                             yes_no_no      312   0    11    48    3     6
# 5                            yes_no_yes     1668  13   314   939  100   197
# 6                            yes_yes_no      755   3    40   111   15    20
# 7                           yes_yes_yes     2776  36   632  2168  210   507
#
# gpt_source_population     na   sa  seap  ssa    we
# 0                       5001   41    31   23   374
# 1                      10464  476   218  284  3304
# 2                       4538   63    25   34   528
# 3                      11150  961   357  428  4047
# 4                        531    1     1   14   115
# 5                       2366   91    40   81  1169
# 6                       1309   20    10   29   311
# 7                       5120  253   141  155  3164

# %%
# Step 7: Categorize studies into European vs. Non-European vs. Unknown (without duplicates)
def classify_region(regions):
    classification = set()
    if any(r in EUROPEAN_REGIONS for r in regions):
        classification.add('European')
    if any(r in NON_EUROPEAN_REGIONS for r in regions):
        classification.add('Non-European')
    if not classification:
        classification.add('Unknown')
    return classification

# Remove rows where gpt_source_population is 'Unknown'


merged_df_unattributable_after_exclusion['classification_group'] = merged_df_unattributable_after_exclusion['normalized_regions'].apply(classify_region)

merged_df_unattributable_after_exclusion_region = merged_df_unattributable_after_exclusion[merged_df_unattributable_after_exclusion['gpt_source_population'] != 'Unknown']

# Compute total counts per classification group
group_totals = merged_df_unattributable_after_exclusion_region['classification_group'].value_counts()

# %%
expanded_rows_region = []
for _, row in merged_df_unattributable_after_exclusion_region.iterrows():
    for group in row['classification_group']:
        new_row = row.copy()
        new_row['classification_group'] = group
        expanded_rows_region.append(new_row)

# Create expanded DataFrame for regional counts
expanded_df_region = pd.DataFrame(expanded_rows_region)
expanded_df_region.shape


summary_expanded_df_region = crosstab_summary(expanded_df_region, categories, region_col='classification_group')

# %%
unknown_classification_rows = expanded_df_region[expanded_df_region['classification_group'] == 'Unknown']
unknown_classification_rows.to_csv(path_equity_precision_llm_folder + '/llm training/epl05_expanded rows region with unknown classification group.csv', index=False)

# %% [markdown]
# ### We need to figure out why there are still Unknowns!
# @aamna: there shouldn't be unknowns at this stage

# %%
# Step 8: Save the expanded output for regions
output_path_group = path_equity_precision_llm_repo + '/preprocessing/epl05_combined_output_Unattributable by group.csv'
summary_expanded_df_region.to_csv(output_path_group, index=False)

# Display summary
display(summary_expanded_df_region)
# Out:
# classification_group combined_category  European  Non-European
# 0                             no_no_no      5325           567
# 1                            no_no_yes     13736          6890
# 2                            no_yes_no      5019           745
# 3                           no_yes_yes     15143          8809
# 4                            yes_no_no       639            81
# 5                           yes_no_yes      3506          1741
# 6                           yes_yes_no      1596           200
# 7                          yes_yes_yes      8182          3940

# %%
merged_df_unattributable_after_exclusion_region = merged_df_unattributable_after_exclusion[
    merged_df_unattributable_after_exclusion['classification_group'].apply(lambda x: 'Unknown' not in x)
]
print("Remaining studies after filtering out Unknown:")
print(merged_df_unattributable_after_exclusion_region.shape)
# Out:
# Remaining studies after filtering out Unknown:
# (75509, 13)

# %%
merged_df_unattributable_after_exclusion.to_csv(path_equity_precision_llm_folder + '/llm training/epl05_output_Unattributable.csv', index=False)
